# %% [markdown]
# # DataPreprocessing --
# Load the dataset using pandas and try atleast 10 functions to explore it
#   -- 10 marks

# %%
import pandas as pd
import numpy as np

# %%
df_red = pd.read_csv('winequality-red.csv')
df_red
# Out:
#      fixed acidity;"volatile acidity";"citric acid";"residual sugar";"chlorides";"free sulfur dioxide";"total sulfur dioxide";"density";"pH";"sulphates";"alcohol";"quality"
# 0      7.4;0.7;0;1.9;0.076;11;34;0.9978;3.51;0.56;9.4;5
# 1      7.8;0.88;0;2.6;0.098;25;67;0.9968;3.2;0.68;9.8;5
# 2     7.8;0.76;0.04;2.3;0.092;15;54;0.997;3.26;0.65;...
# 3     11.2;0.28;0.56;1.9;0.075;17;60;0.998;3.16;0.58...
# 4      7.4;0.7;0;1.9;0.076;11;34;0.9978;3.51;0.56;9.4;5
# ...                                                 ...
# 1594  6.2;0.6;0.08;2;0.09;32;44;0.9949;3.45;0.58;10.5;5
# 1595  5.9;0.55;0.1;2.2;0.062;39;51;0.99512;3.52;0.76...
# 1596  6.3;0.51;0.13;2.3;0.076;29;40;0.99574;3.42;0.7...
# 1597  5.9;0.645;0.12;2;0.075;32;44;0.99547;3.57;0.71...
# 1598  6;0.31;0.47;3.6;0.067;18;42;0.99549;3.39;0.66;...
#
# [1599 rows x 1 columns]

# %%
df1_red = pd.read_table('winequality-red.csv',sep=';')
df1_red
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4             0.700         0.00             1.9      0.076
# 1               7.8             0.880         0.00             2.6      0.098
# 2               7.8             0.760         0.04             2.3      0.092
# 3              11.2             0.280         0.56             1.9      0.075
# 4               7.4             0.700         0.00             1.9      0.076
# ...             ...               ...          ...             ...        ...
# 1594            6.2             0.600         0.08             2.0      0.090
# 1595            5.9             0.550         0.10             2.2      0.062
# 1596            6.3             0.510         0.13             2.3      0.076
# 1597            5.9             0.645         0.12             2.0      0.075
# 1598            6.0             0.310         0.47             3.6      0.067
#
# ...

# %%
df_white = pd.read_csv('winequality-white.csv')
df_white
# Out:
#      fixed acidity;"volatile acidity";"citric acid";"residual sugar";"chlorides";"free sulfur dioxide";"total sulfur dioxide";"density";"pH";"sulphates";"alcohol";"quality"
# 0      7;0.27;0.36;20.7;0.045;45;170;1.001;3;0.45;8.8;6
# 1     6.3;0.3;0.34;1.6;0.049;14;132;0.994;3.3;0.49;9...
# 2     8.1;0.28;0.4;6.9;0.05;30;97;0.9951;3.26;0.44;1...
# 3     7.2;0.23;0.32;8.5;0.058;47;186;0.9956;3.19;0.4...
# 4     7.2;0.23;0.32;8.5;0.058;47;186;0.9956;3.19;0.4...
# ...                                                 ...
# 4893  6.2;0.21;0.29;1.6;0.039;24;92;0.99114;3.27;0.5...
# 4894  6.6;0.32;0.36;8;0.047;57;168;0.9949;3.15;0.46;...
# 4895  6.5;0.24;0.19;1.2;0.041;30;111;0.99254;2.99;0....
# 4896  5.5;0.29;0.3;1.1;0.022;20;110;0.98869;3.34;0.3...
# 4897  6;0.21;0.38;0.8;0.02;22;98;0.98941;3.26;0.32;1...
#
# [4898 rows x 1 columns]

# %%
df1_white = pd.read_table('winequality-white.csv',sep = ';')
df1_white
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.0              0.27         0.36            20.7      0.045
# 1               6.3              0.30         0.34             1.6      0.049
# 2               8.1              0.28         0.40             6.9      0.050
# 3               7.2              0.23         0.32             8.5      0.058
# 4               7.2              0.23         0.32             8.5      0.058
# ...             ...               ...          ...             ...        ...
# 4893            6.2              0.21         0.29             1.6      0.039
# 4894            6.6              0.32         0.36             8.0      0.047
# 4895            6.5              0.24         0.19             1.2      0.041
# 4896            5.5              0.29         0.30             1.1      0.022
# 4897            6.0              0.21         0.38             0.8      0.020
#
# ...

# %%
df1_red.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol  quality
# 0      9.4        5
# 1      9.8        5
# 2      9.8        5
# ...

# %%
df1_white.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.0              0.27         0.36            20.7      0.045
# 1            6.3              0.30         0.34             1.6      0.049
# 2            8.1              0.28         0.40             6.9      0.050
# 3            7.2              0.23         0.32             8.5      0.058
# 4            7.2              0.23         0.32             8.5      0.058
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 45.0                 170.0   1.0010  3.00       0.45
# 1                 14.0                 132.0   0.9940  3.30       0.49
# 2                 30.0                  97.0   0.9951  3.26       0.44
# 3                 47.0                 186.0   0.9956  3.19       0.40
# 4                 47.0                 186.0   0.9956  3.19       0.40
#
#    alcohol  quality
# 0      8.8        6
# 1      9.5        6
# 2     10.1        6
# ...

# %%
df1_red.tail()
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 1594            6.2             0.600         0.08             2.0      0.090
# 1595            5.9             0.550         0.10             2.2      0.062
# 1596            6.3             0.510         0.13             2.3      0.076
# 1597            5.9             0.645         0.12             2.0      0.075
# 1598            6.0             0.310         0.47             3.6      0.067
#
#       free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 1594                 32.0                  44.0  0.99490  3.45       0.58
# 1595                 39.0                  51.0  0.99512  3.52       0.76
# 1596                 29.0                  40.0  0.99574  3.42       0.75
# 1597                 32.0                  44.0  0.99547  3.57       0.71
# 1598                 18.0                  42.0  0.99549  3.39       0.66
#
#       alcohol  quality
# 1594     10.5        5
# ...

# %%
df1_white.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.0              0.27         0.36            20.7      0.045
# 1            6.3              0.30         0.34             1.6      0.049
# 2            8.1              0.28         0.40             6.9      0.050
# 3            7.2              0.23         0.32             8.5      0.058
# 4            7.2              0.23         0.32             8.5      0.058
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 45.0                 170.0   1.0010  3.00       0.45
# 1                 14.0                 132.0   0.9940  3.30       0.49
# 2                 30.0                  97.0   0.9951  3.26       0.44
# 3                 47.0                 186.0   0.9956  3.19       0.40
# 4                 47.0                 186.0   0.9956  3.19       0.40
#
#    alcohol  quality
# 0      8.8        6
# 1      9.5        6
# 2     10.1        6
# ...

# %%
df1_white.tail()
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 4893            6.2              0.21         0.29             1.6      0.039
# 4894            6.6              0.32         0.36             8.0      0.047
# 4895            6.5              0.24         0.19             1.2      0.041
# 4896            5.5              0.29         0.30             1.1      0.022
# 4897            6.0              0.21         0.38             0.8      0.020
#
#       free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 4893                 24.0                  92.0  0.99114  3.27       0.50
# 4894                 57.0                 168.0  0.99490  3.15       0.46
# 4895                 30.0                 111.0  0.99254  2.99       0.46
# 4896                 20.0                 110.0  0.98869  3.34       0.38
# 4897                 22.0                  98.0  0.98941  3.26       0.32
#
#       alcohol  quality
# 4893     11.2        6
# ...

# %%
df1_red.columns
# Out:
# Index(['fixed acidity', 'volatile acidity', 'citric acid', 'residual sugar',
#        'chlorides', 'free sulfur dioxide', 'total sulfur dioxide', 'density',
#        'pH', 'sulphates', 'alcohol', 'quality'],
#       dtype='object')

# %%
df1_white.columns
# Out:
# Index(['fixed acidity', 'volatile acidity', 'citric acid', 'residual sugar',
#        'chlorides', 'free sulfur dioxide', 'total sulfur dioxide', 'density',
#        'pH', 'sulphates', 'alcohol', 'quality'],
#       dtype='object')

# %%
df1_red.shape
# Out:
# (1599, 12)

# %%
df1_white.shape
# Out:
# (4898, 12)

# %%
df1_red.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1599 entries, 0 to 1598
# Data columns (total 12 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   fixed acidity         1599 non-null   float64
#  1   volatile acidity      1599 non-null   float64
#  2   citric acid           1599 non-null   float64
#  3   residual sugar        1599 non-null   float64
#  4   chlorides             1599 non-null   float64
#  5   free sulfur dioxide   1599 non-null   float64
#  6   total sulfur dioxide  1599 non-null   float64
#  7   density               1599 non-null   float64
#  8   pH                    1599 non-null   float64
#  9   sulphates             1599 non-null   float64
#  10  alcohol               1599 non-null   float64
#  11  quality               1599 non-null   int64
# dtypes: float64(11), int64(1)
# memory usage: 150.0 KB

# %%
df1_white.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4898 entries, 0 to 4897
# Data columns (total 12 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   fixed acidity         4898 non-null   float64
#  1   volatile acidity      4898 non-null   float64
#  2   citric acid           4898 non-null   float64
#  3   residual sugar        4898 non-null   float64
#  4   chlorides             4898 non-null   float64
#  5   free sulfur dioxide   4898 non-null   float64
#  6   total sulfur dioxide  4898 non-null   float64
#  7   density               4898 non-null   float64
#  8   pH                    4898 non-null   float64
#  9   sulphates             4898 non-null   float64
#  10  alcohol               4898 non-null   float64
#  11  quality               4898 non-null   int64
# dtypes: float64(11), int64(1)
# memory usage: 459.3 KB

# %%
df1_red.describe()
# Out:
#        fixed acidity  volatile acidity  citric acid  residual sugar  \
# count    1599.000000       1599.000000  1599.000000     1599.000000
# mean        8.319637          0.527821     0.270976        2.538806
# std         1.741096          0.179060     0.194801        1.409928
# min         4.600000          0.120000     0.000000        0.900000
# 25%         7.100000          0.390000     0.090000        1.900000
# 50%         7.900000          0.520000     0.260000        2.200000
# 75%         9.200000          0.640000     0.420000        2.600000
# max        15.900000          1.580000     1.000000       15.500000
#
#          chlorides  free sulfur dioxide  total sulfur dioxide      density  \
# count  1599.000000          1599.000000           1599.000000  1599.000000
# mean      0.087467            15.874922             46.467792     0.996747
# std       0.047065            10.460157             32.895324     0.001887
# ...

# %%
df1_white.describe()
# Out:
#        fixed acidity  volatile acidity  citric acid  residual sugar  \
# count    4898.000000       4898.000000  4898.000000     4898.000000
# mean        6.854788          0.278241     0.334192        6.391415
# std         0.843868          0.100795     0.121020        5.072058
# min         3.800000          0.080000     0.000000        0.600000
# 25%         6.300000          0.210000     0.270000        1.700000
# 50%         6.800000          0.260000     0.320000        5.200000
# 75%         7.300000          0.320000     0.390000        9.900000
# max        14.200000          1.100000     1.660000       65.800000
#
#          chlorides  free sulfur dioxide  total sulfur dioxide      density  \
# count  4898.000000          4898.000000           4898.000000  4898.000000
# mean      0.045772            35.308085            138.360657     0.994027
# std       0.021848            17.007137             42.498065     0.002991
# ...

# %%
df1_red.describe
# Out:
# <bound method NDFrame.describe of       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4             0.700         0.00             1.9      0.076
# 1               7.8             0.880         0.00             2.6      0.098
# 2               7.8             0.760         0.04             2.3      0.092
# 3              11.2             0.280         0.56             1.9      0.075
# 4               7.4             0.700         0.00             1.9      0.076
# ...             ...               ...          ...             ...        ...
# 1594            6.2             0.600         0.08             2.0      0.090
# 1595            5.9             0.550         0.10             2.2      0.062
# 1596            6.3             0.510         0.13             2.3      0.076
# 1597            5.9             0.645         0.12             2.0      0.075
# 1598            6.0             0.310         0.47             3.6      0.067
#
# ...

# %%
df1_white.describe
# Out:
# <bound method NDFrame.describe of       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.0              0.27         0.36            20.7      0.045
# 1               6.3              0.30         0.34             1.6      0.049
# 2               8.1              0.28         0.40             6.9      0.050
# 3               7.2              0.23         0.32             8.5      0.058
# 4               7.2              0.23         0.32             8.5      0.058
# ...             ...               ...          ...             ...        ...
# 4893            6.2              0.21         0.29             1.6      0.039
# 4894            6.6              0.32         0.36             8.0      0.047
# 4895            6.5              0.24         0.19             1.2      0.041
# 4896            5.5              0.29         0.30             1.1      0.022
# 4897            6.0              0.21         0.38             0.8      0.020
#
# ...

# %%
df1_red.dtypes
df1_white.dtypes
# Out:
# fixed acidity           float64
# volatile acidity        float64
# citric acid             float64
# residual sugar          float64
# chlorides               float64
# free sulfur dioxide     float64
# total sulfur dioxide    float64
# density                 float64
# pH                      float64
# sulphates               float64
# alcohol                 float64
# quality                   int64
# dtype: object

# %%
df1_red.duplicated().any()
df1_white.duplicated().any()
# Out:
# True

# %% [markdown]
# <h4>There are duplicates in both the csv files assigned to the variables "df_red" and "df_white"</h4>

# %%
df1_red.drop_duplicates(inplace=True)  # Removing duplicates and modifying the original dataframe

# %%
df1_red.duplicated().any()
# Out:
# False

# %%
df1_white.drop_duplicates(inplace=True)

# %%
df1_white.duplicated().any()
# Out:
# False

# %%
df1_red.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 5            7.4              0.66         0.00             1.8      0.075
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 5                 13.0                  40.0   0.9978  3.51       0.56
#
#    alcohol  quality
# 0      9.4        5
# 1      9.8        5
# 2      9.8        5
# ...

# %% [markdown]
# <h4>The above 5 lines of code is implemented inorder to remove the duplicates present and modify the original dataframes accordingly. Hence the duplicates are deleted</h4>

# %% [markdown]
# <h4>Checking for missing values</h4>

# %%
df1_red.isnull()
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0             False             False        False           False      False
# 1             False             False        False           False      False
# 2             False             False        False           False      False
# 3             False             False        False           False      False
# 5             False             False        False           False      False
# ...             ...               ...          ...             ...        ...
# 1593          False             False        False           False      False
# 1594          False             False        False           False      False
# 1595          False             False        False           False      False
# 1597          False             False        False           False      False
# 1598          False             False        False           False      False
#
# ...

# %%
df1_white.isnull()
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0             False             False        False           False      False
# 1             False             False        False           False      False
# 2             False             False        False           False      False
# 3             False             False        False           False      False
# 6             False             False        False           False      False
# ...             ...               ...          ...             ...        ...
# 4893          False             False        False           False      False
# 4894          False             False        False           False      False
# 4895          False             False        False           False      False
# 4896          False             False        False           False      False
# 4897          False             False        False           False      False
#
# ...

# %%
df1_red.isnull().sum()
# Out:
# fixed acidity           0
# volatile acidity        0
# citric acid             0
# residual sugar          0
# chlorides               0
# free sulfur dioxide     0
# total sulfur dioxide    0
# density                 0
# pH                      0
# sulphates               0
# alcohol                 0
# quality                 0
# dtype: int64

# %%
df1_white.isnull().sum()
# Out:
# fixed acidity           0
# volatile acidity        0
# citric acid             0
# residual sugar          0
# chlorides               0
# free sulfur dioxide     0
# total sulfur dioxide    0
# density                 0
# pH                      0
# sulphates               0
# alcohol                 0
# quality                 0
# dtype: int64

# %%
df1_red.notnull()
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0              True              True         True            True       True
# 1              True              True         True            True       True
# 2              True              True         True            True       True
# 3              True              True         True            True       True
# 5              True              True         True            True       True
# ...             ...               ...          ...             ...        ...
# 1593           True              True         True            True       True
# 1594           True              True         True            True       True
# 1595           True              True         True            True       True
# 1597           True              True         True            True       True
# 1598           True              True         True            True       True
#
# ...

# %%
df1_white.notnull()
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0              True              True         True            True       True
# 1              True              True         True            True       True
# 2              True              True         True            True       True
# 3              True              True         True            True       True
# 6              True              True         True            True       True
# ...             ...               ...          ...             ...        ...
# 4893           True              True         True            True       True
# 4894           True              True         True            True       True
# 4895           True              True         True            True       True
# 4896           True              True         True            True       True
# 4897           True              True         True            True       True
#
# ...

# %%
df1_red.notnull().sum()
# Out:
# fixed acidity           1359
# volatile acidity        1359
# citric acid             1359
# residual sugar          1359
# chlorides               1359
# free sulfur dioxide     1359
# total sulfur dioxide    1359
# density                 1359
# pH                      1359
# sulphates               1359
# alcohol                 1359
# quality                 1359
# dtype: int64

# %%
df1_white.notnull().sum()
# Out:
# fixed acidity           3961
# volatile acidity        3961
# citric acid             3961
# residual sugar          3961
# chlorides               3961
# free sulfur dioxide     3961
# total sulfur dioxide    3961
# density                 3961
# pH                      3961
# sulphates               3961
# alcohol                 3961
# quality                 3961
# dtype: int64

# %% [markdown]
# <h4>There are no missing values in both the csv files</h4>

# %%
df1_red.nunique()
# Out:
# fixed acidity            96
# volatile acidity        143
# citric acid              80
# residual sugar           91
# chlorides               153
# free sulfur dioxide      60
# total sulfur dioxide    144
# density                 436
# pH                       89
# sulphates                96
# alcohol                  65
# quality                   6
# dtype: int64

# %%
df1_white.nunique()
# Out:
# fixed acidity            68
# volatile acidity        125
# citric acid              87
# residual sugar          310
# chlorides               160
# free sulfur dioxide     132
# total sulfur dioxide    251
# density                 890
# pH                      103
# sulphates                79
# alcohol                 103
# quality                   7
# dtype: int64

# %% [markdown]
# # Data Visualizations
#
# atleast 10 graphs on the dataset -- different and relevant types required --

# %% [markdown]
# <h4>This heatmap shows depicts the null values present</h4>

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
sns.heatmap(df_red.isnull(),yticklabels=False,cbar=False , cmap='viridis')
plt.show()

# %%
r_correlations = df1_red.corr()['quality'].drop('quality')
print(r_correlations)
# Out:
# fixed acidity           0.119024
# volatile acidity       -0.395214
# citric acid             0.228057
# residual sugar          0.013640
# chlorides              -0.130988
# free sulfur dioxide    -0.050463
# total sulfur dioxide   -0.177855
# density                -0.184252
# pH                     -0.055245
# sulphates               0.248835
# alcohol                 0.480343
# Name: quality, dtype: float64

# %%
sns.heatmap(df1_red.corr())
plt.show()

# %%
plt.figure(figsize=(10,10))
sns.heatmap(df1_red.corr(),annot = True , cmap = 'coolwarm')
# Out:
# <Axes: >

# %%
sns.set()
fig = df1_red.hist(figsize=(15,10), color='red', xlabelsize=8, ylabelsize=8)
[x.title.set_size(8) for x in fig.ravel()]
plt.show()

# %%
sns.set()
fig = df1_white.hist(figsize=(15,10), color='#5F9EA0', xlabelsize=8, ylabelsize=8)
[x.title.set_size(8) for x in fig.ravel()]
plt.show()

# %%
for (col) in df1_red.columns:
  sns.histplot(data=df1_red,x=col, kde=True,hue = 'quality')
  plt.show()

# %%
for (col) in df1_white.columns:
  sns.histplot(data=df1_white,x=col, kde=True, palette = 'ocean' , hue = 'quality')
  plt.show()

# %%
for (col) in df1_red.columns :
  sns.boxplot(data = df1_red,x = col)
  plt.show()

# %%
for (col) in df1_white.columns :
  sns.boxplot(data = df1_white,x = col,color = 'coral')
  plt.show()

# %%
r_corr_matrix = df1_red.corr()
r_corr_matrix
# Out:
#                       fixed acidity  volatile acidity  citric acid  \
# fixed acidity              1.000000         -0.255124     0.667437
# volatile acidity          -0.255124          1.000000    -0.551248
# citric acid                0.667437         -0.551248     1.000000
# residual sugar             0.111025         -0.002449     0.143892
# chlorides                  0.085886          0.055154     0.210195
# free sulfur dioxide       -0.140580         -0.020945    -0.048004
# total sulfur dioxide      -0.103777          0.071701     0.047358
# density                    0.670195          0.023943     0.357962
# pH                        -0.686685          0.247111    -0.550310
# sulphates                  0.190269         -0.256948     0.326062
# alcohol                   -0.061596         -0.197812     0.105108
# quality                    0.119024         -0.395214     0.228057
#
#                       residual sugar  chlorides  free sulfur dioxide  \
# ...

# %%
r_corr_matrix1=r_corr_matrix.abs()
upper_tri = r_corr_matrix1.where(np.triu(np.ones(r_corr_matrix1.shape),k=1).astype(np.bool_))
upper_tri
# Out:
#                       fixed acidity  volatile acidity  citric acid  \
# fixed acidity                   NaN          0.255124     0.667437
# volatile acidity                NaN               NaN     0.551248
# citric acid                     NaN               NaN          NaN
# residual sugar                  NaN               NaN          NaN
# chlorides                       NaN               NaN          NaN
# free sulfur dioxide             NaN               NaN          NaN
# total sulfur dioxide            NaN               NaN          NaN
# density                         NaN               NaN          NaN
# pH                              NaN               NaN          NaN
# sulphates                       NaN               NaN          NaN
# alcohol                         NaN               NaN          NaN
# quality                         NaN               NaN          NaN
#
#                       residual sugar  chlorides  free sulfur dioxide  \
# ...

# %%
r_matrix = np.triu(r_corr_matrix)
sns.heatmap(df1_red.corr(),annot = True, linewidth=.8, mask=r_matrix,cmap="rocket",cbar=False)
# Out:
# <Axes: >

# %%
w_corr_matrix = df1_white.corr()
w_corr_matrix
# Out:
#                       fixed acidity  volatile acidity  citric acid  \
# fixed acidity              1.000000         -0.019214     0.298959
# volatile acidity          -0.019214          1.000000    -0.163228
# citric acid                0.298959         -0.163228     1.000000
# residual sugar             0.083620          0.098340     0.106269
# chlorides                  0.024036          0.086287     0.132590
# free sulfur dioxide       -0.058396         -0.102471     0.091681
# total sulfur dioxide       0.082425          0.102315     0.122845
# density                    0.266091          0.060603     0.160076
# pH                        -0.431274         -0.046954    -0.183015
# sulphates                 -0.017453         -0.021150     0.049442
# alcohol                   -0.110788          0.046815    -0.076514
# quality                   -0.124636         -0.190678     0.007065
#
#                       residual sugar  chlorides  free sulfur dioxide  \
# ...

# %%
w_corr_matrix1=w_corr_matrix.abs()
lower_tri = w_corr_matrix1.where(np.tril(np.ones(w_corr_matrix1.shape),k=1).astype(np.bool_))
lower_tri
# Out:
#                       fixed acidity  volatile acidity  citric acid  \
# fixed acidity              1.000000          0.019214          NaN
# volatile acidity           0.019214          1.000000     0.163228
# citric acid                0.298959          0.163228     1.000000
# residual sugar             0.083620          0.098340     0.106269
# chlorides                  0.024036          0.086287     0.132590
# free sulfur dioxide        0.058396          0.102471     0.091681
# total sulfur dioxide       0.082425          0.102315     0.122845
# density                    0.266091          0.060603     0.160076
# pH                         0.431274          0.046954     0.183015
# sulphates                  0.017453          0.021150     0.049442
# alcohol                    0.110788          0.046815     0.076514
# quality                    0.124636          0.190678     0.007065
#
#                       residual sugar  chlorides  free sulfur dioxide  \
# ...

# %%
w_matrix = np.tril(w_corr_matrix)
sns.heatmap(df1_white.corr(),annot = True, linewidth=.8, mask=w_matrix,cmap="mako",cbar=False)
# Out:
# <Axes: >

# %% [markdown]
# #  Model
# Use any number ML models(regression or classification based on the problem)  of your interest, use relevant metrics  also -- - find better features of interest in given data--  20 marks

# %% [markdown]
# <h4>Working on the file winequality-red.csv i.e., predicting the quality of red wine</h4>

# %%
from sklearn.preprocessing import StandardScaler
std_scaler = StandardScaler()

# %%
x1_scaled = std_scaler.fit_transform(x1)
x1_scaled
# Out:
# array([[-0.52443096,  0.93200015, -1.39325797, ...,  1.29187216,
#         -0.57856134, -0.95437429],
#        [-0.29406274,  1.91580043, -1.39325797, ..., -0.70839548,
#          0.12482157, -0.5845748 ],
#        [-0.29406274,  1.25993358, -1.18861732, ..., -0.32124691,
#         -0.05102416, -0.5845748 ],
#        ...,
#        [-1.38831178,  0.11216658, -0.88165635, ...,  1.35639693,
#          0.59374351,  0.7097234 ],
#        [-1.38831178,  0.63139451, -0.77933603, ...,  1.67902074,
#          0.3006673 , -0.21477532],
#        [-1.33071973, -1.19956712,  1.01126962, ...,  0.51757501,
#          0.00759108,  0.52482366]])

# %%
from sklearn.model_selection import train_test_split
x1_train, x1_test, y1_train, y1_test = train_test_split(x1_scaled,y1,test_size=0.2,random_state= 42,stratify =y1)

# %%
x1_train.shape , x1_test.shape
# Out:
# ((1087, 11), (272, 11))

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import ExtraTreesClassifier
from sklearn.svm import SVC
from sklearn.neighbors import KNeighborsClassifier
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn.ensemble import AdaBoostClassifier

# %%
LOR = LogisticRegression()
DT = DecisionTreeClassifier()
RF = RandomForestClassifier()
ETC = ExtraTreesClassifier()
SVM = SVC()
KNN = KNeighborsClassifier()
GBC = GradientBoostingClassifier()
ABC = AdaBoostClassifier()
NB = GaussianNB()

# %%
from sklearn.model_selection import cross_val_score

# %%
cls_models = [LOR,DT,RF,ETC,SVM,KNN,GBC,ABC,NB]
features = x1_scaled
labels = y1
CV = 5
accu_list = [] #Accuracy List
ModelName = [] #Model Name List

for model in cls_models:
  model_name = model.__class__.__name__
  accuracies = cross_val_score(model,features,labels,scoring = 'accuracy',cv = CV)
  accu_list.append(accuracies.mean()*100)
  ModelName.append(model_name)

model_acc_df = pd.DataFrame({"Model" : ModelName , "Cross_Val_Accuracy" : accu_list})
model_acc_df
# Out:
# /home/rgukt/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_logistic.py:460: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
#                         Model  Cross_Val_Accuracy
# 0          LogisticRegression           57.544769
# 1      DecisionTreeClassifier           46.872422
# 2      RandomForestClassifier           56.734046
# 3        ExtraTreesClassifier           56.881105
# 4                         SVC           58.351150
# 5        KNeighborsClassifier           52.097352
# 6  GradientBoostingClassifier           55.482147
# ...

# %% [markdown]
# <h2>Metrics</h2>

# %%
from sklearn.metrics import classification_report

# %%
SVM.fit(x1_train, y1_train)
ETC.fit(x1_train, y1_train)
RF.fit(x1_train, y1_train)
y1_pred_rf = RF.predict(x1_test)
y1_pred_svm = SVM.predict(x1_test)
y1_pred_etc = ETC.predict(x1_test)

# %%
print(classification_report(y1_test, y1_pred_rf,zero_division=0.0))
# Out:
#               precision    recall  f1-score   support
#
#            3       0.00      0.00      0.00         2
#            4       0.00      0.00      0.00        11
#            5       0.69      0.73      0.71       116
#            6       0.57      0.66      0.61       107
#            7       0.42      0.24      0.31        33
#            8       0.00      0.00      0.00         3
#
#     accuracy                           0.60       272
#    macro avg       0.28      0.27      0.27       272
# weighted avg       0.57      0.60      0.58       272

# %%
print(classification_report(y1_test, y1_pred_svm, zero_division=0.0))
# Out:
#               precision    recall  f1-score   support
#
#            3       0.00      0.00      0.00         2
#            4       0.00      0.00      0.00        11
#            5       0.67      0.74      0.70       116
#            6       0.54      0.64      0.59       107
#            7       0.44      0.24      0.31        33
#            8       0.00      0.00      0.00         3
#
#     accuracy                           0.60       272
#    macro avg       0.28      0.27      0.27       272
# weighted avg       0.55      0.60      0.57       272

# %%
from sklearn.metrics import confusion_matrix, classification_report
cm = confusion_matrix(y1_test, y1_pred_svm)
print("Confusion Matrix:\n", cm)
# Out:
# Confusion Matrix:
#  [[ 0  0  1  1  0  0]
#  [ 0  0  9  2  0  0]
#  [ 0  0 86 29  1  0]
#  [ 0  0 31 68  8  0]
#  [ 0  0  2 23  8  0]
#  [ 0  0  0  2  1  0]]

# %% [markdown]
# <h4> we are trying the <b>Random forest model</b> as the difference between the metrics is very low</h4>

# %%
from sklearn.model_selection import GridSearchCV, RandomizedSearchCV
from sklearn.model_selection import StratifiedKFold

params_RF = {"min_samples_split":[2,6],
             "min_samples_leaf":[1,4],
             "n_estimators":[100,200,300],
             "criterion":["gini",'entropy']
}

cv_method = StratifiedKFold(n_splits=3)
GridSearchCV_RF = GridSearchCV(estimator=RandomForestClassifier(),
                               param_grid=params_RF,
                               cv=cv_method,
                               verbose=1,
                               n_jobs=2,
                               scoring="accuracy",
                               return_train_score=True
                               )

GridSearchCV_RF.fit(x1_train,y1_train)
best_params_RF = GridSearchCV_RF.best_params_
print("Best Hyperparameters for Random Forest aer = ", best_params_RF)
# Out:
# Fitting 3 folds for each of 24 candidates, totalling 72 fits
# Best Hyperparameters for Random Forest aer =  {'criterion': 'entropy', 'min_samples_leaf': 1, 'min_samples_split': 6, 'n_estimators': 300}

# %%
best_estimator = GridSearchCV_RF.best_estimator_
best_estimator.fit(x1_train,y1_train)
y1_pred_best = best_estimator.predict(x1_test)
print(classification_report(y1_test,y1_pred_best,zero_division=0.0))
# Out:
#               precision    recall  f1-score   support
#
#            3       0.00      0.00      0.00         2
#            4       0.00      0.00      0.00        11
#            5       0.68      0.73      0.71       116
#            6       0.55      0.64      0.59       107
#            7       0.52      0.33      0.41        33
#            8       0.00      0.00      0.00         3
#
#     accuracy                           0.61       272
#    macro avg       0.29      0.29      0.28       272
# weighted avg       0.57      0.61      0.58       272

# %%
from sklearn.metrics import accuracy_score
print(f"Accuracy of Random Forest Model = {round(accuracy_score(y1_test,y1_pred_best)*100,2)}%")
# Out:
# Accuracy of Random Forest Model = 60.66%

# %% [markdown]
# <h3>The Random Forest Model is predicting the quality of red wine with an accuracy of <b>60.66%</b></h3>

# %% [markdown]
# <h3>Trying different classification models to predict the quality of red wine by calculating the accuracy and cross validation scores</h3>

# %%
x1=df1_red.drop(columns=['quality'])
y1=df1_red['quality']
from sklearn.model_selection import cross_val_score, train_test_split
def classify(model, x1, y1):
   x1_train, x1_test, y1_train, y1_test=train_test_split(x1, y1, test_size=0.25, random_state=42)
#train the model
   model.fit(x1_train, y1_train)
   print("Accuracy:", model.score(x1_test, y1_test)*100)
#cross-validation
   score=cross_val_score(model, x1, y1, cv=5) 
   print("CV Score:", np.mean(score) *100)

# %% [markdown]
# <h3>The Logistic Regression Model is predicting the quality of red wine with an accuracy of <b>59.12%</b></h3>

# %%
from sklearn.linear_model import LogisticRegression
model= LogisticRegression()
classify(model, x1, y1)
# Out:
# /home/rgukt/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_logistic.py:460: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/rgukt/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_logistic.py:460: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
# ...

# %% [markdown]
# <h3>The Decision Trees Classifier Model is predicting the quality of red wine with an accuracy of <b>50%</b></h3>

# %%
from sklearn.tree import DecisionTreeClassifier
model= DecisionTreeClassifier()
classify(model, x1, y1)
# Out:
# Accuracy: 49.705882352941174
# CV Score: 46.64993488170175

# %% [markdown]
# <h3>The Extra Trees Classifier Model is predicting the quality of red wine with an accuracy of <b>61.8%</b></h3>

# %%
from sklearn.tree import ExtraTreeClassifier
model= ExtraTreesClassifier()
classify(model, x1, y1)
# Out:
# Accuracy: 61.47058823529412
# CV Score: 56.65943130019535

# %% [markdown]
# <h3>The GradientBoostingClassifier Model is predicting the quality of red wine with an accuracy of <b>59.12%</b></h3>

# %%
from sklearn.ensemble import GradientBoostingClassifier
model= GradientBoostingClassifier()
classify(model, x1, y1)
# Out:
# Accuracy: 59.11764705882353
# CV Score: 54.52436509659214

# %% [markdown]
# <h3>The GaussianNB Model is predicting the quality of red wine with an accuracy of <b>55.3%</b></h3>

# %%
from sklearn.naive_bayes import GaussianNB
model= GaussianNB()
classify(model, x1, y1)
# Out:
# Accuracy: 55.294117647058826
# CV Score: 51.732960711960054

# %% [markdown]
# <h3>The AdaBoostClassifier Model is predicting the quality of red wine with an accuracy of <b>54.41%</b></h3>

# %%
from sklearn.ensemble import AdaBoostClassifier
model= AdaBoostClassifier()
classify(model, x1, y1)
# Out:
# Accuracy: 54.41176470588235
# CV Score: 51.80486216626872

# %% [markdown]
# <h3>The SVC Model is predicting the quality of red wine with an accuracy of <b>49.41%</b></h3>

# %%
from sklearn.svm import SVC
model= SVC()
classify(model , x1 , y1)
# Out:
# Accuracy: 49.411764705882355
# CV Score: 49.739526807032775

# %% [markdown]
# <h3>The KNeighborsClassifier Model is predicting the quality of red wine with an accuracy of <b>46.5%</b></h3>

# %%
from sklearn.neighbors import KNeighborsClassifier
model= KNeighborsClassifier()
classify(model , x1 , y1)
# Out:
# Accuracy: 46.470588235294116
# CV Score: 44.66545474278273

# %%
"The best model predicting the quality of Red wine obtained is Extra Trees Classifier model with 61.8% accuracy"
# Out:
# 'The best model predicting the quality of Red wine obtained is Extra Trees Classifier model with 61.8% accuracy'

# %% [markdown]
# <h4>Woriking on the file winequality-white.csv inorder to predict the quality of <b>white wine</b></h4>

# %%
y2 = df1_white['quality']
x2 = df1_white.drop('quality', axis=1)

# %%
from sklearn.preprocessing import StandardScaler
std_scaler = StandardScaler()

# %%
x2_scaled = std_scaler.fit_transform(x2)
x2_scaled
# Out:
# array([[ 0.18535197, -0.10188873,  0.20965146, ..., -1.28992816,
#         -0.35548818, -1.47039574],
#        [-0.6222624 ,  0.18817926,  0.04629365, ...,  0.68992438,
#         -0.00309159, -0.89517431],
#        [ 1.45446025, -0.0051994 ,  0.53636707, ...,  0.42594404,
#         -0.44358733, -0.40212736],
#        ...,
#        [-0.39151544, -0.39195672, -1.17888992, ..., -1.35592325,
#         -0.26738904, -0.9773488 ],
#        [-1.54525024,  0.09148993, -0.28042197, ...,  0.95390472,
#         -0.97218223,  1.81658387],
#        [-0.96838284, -0.6820247 ,  0.37300927, ...,  0.42594404,
#         -1.50077712,  0.99483897]])

# %%
from sklearn.model_selection import train_test_split
x2_train, x2_test, y2_train, y2_test = train_test_split(x2_scaled,y2,test_size=0.2,random_state= 42,stratify =y2)

# %%
x2_train.shape , x2_test.shape
# Out:
# ((3168, 11), (793, 11))

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import ExtraTreesClassifier
from sklearn.svm import SVC
from sklearn.neighbors import KNeighborsClassifier
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn.ensemble import AdaBoostClassifier

# %%
LOR = LogisticRegression()
DT = DecisionTreeClassifier()
RF = RandomForestClassifier()
ETC = ExtraTreesClassifier()
SVM = SVC()
KNN = KNeighborsClassifier()
GBC = GradientBoostingClassifier()
ABC = AdaBoostClassifier()
NB = GaussianNB()

# %%
from sklearn.model_selection import cross_val_score

# %%
from sklearn.metrics import classification_report

# %%
SVM.fit(x2_train, y2_train)
ETC.fit(x2_train, y2_train)
RF.fit(x2_train, y2_train)
y2_pred_rf = RF.predict(x2_test)
y2_pred_svm = SVM.predict(x2_test)
y2_pred_etc = ETC.predict(x2_test)

# %%
print(classification_report(y2_test, y2_pred_rf,zero_division=0.0))
# Out:
#               precision    recall  f1-score   support
#
#            3       0.00      0.00      0.00         4
#            4       0.60      0.19      0.29        31
#            5       0.61      0.57      0.59       235
#            6       0.55      0.75      0.64       358
#            7       0.49      0.29      0.37       138
#            8       0.50      0.04      0.07        26
#            9       0.00      0.00      0.00         1
#
#     accuracy                           0.56       793
#    macro avg       0.39      0.26      0.28       793
# weighted avg       0.56      0.56      0.54       793

# %%
print(classification_report(y2_test, y2_pred_svm, zero_division=0.0))
# Out:
#               precision    recall  f1-score   support
#
#            3       0.00      0.00      0.00         4
#            4       0.40      0.06      0.11        31
#            5       0.59      0.57      0.58       235
#            6       0.54      0.77      0.63       358
#            7       0.56      0.20      0.30       138
#            8       0.00      0.00      0.00        26
#            9       0.00      0.00      0.00         1
#
#     accuracy                           0.55       793
#    macro avg       0.30      0.23      0.23       793
# weighted avg       0.53      0.55      0.51       793

# %%
from sklearn.metrics import confusion_matrix, classification_report
cm = confusion_matrix(y2_test, y2_pred_svm)
print("Confusion Matrix:\n", cm)
# Out:
# Confusion Matrix:
#  [[  0   0   2   2   0   0   0]
#  [  0   2  20   9   0   0   0]
#  [  0   3 135  96   1   0   0]
#  [  0   0  69 274  15   0   0]
#  [  0   0   2 108  28   0   0]
#  [  0   0   0  21   5   0   0]
#  [  0   0   0   0   1   0   0]]

# %% [markdown]
# <h4> we are trying the <b>Random forest model</b> as the difference between the metrics is very low</h4>

# %%
from sklearn.model_selection import GridSearchCV, RandomizedSearchCV
from sklearn.model_selection import StratifiedKFold

params_RF = {"min_samples_split":[2,6],
             "min_samples_leaf":[1,4],
             "n_estimators":[100,200,300],
             "criterion":["gini",'entropy']
}

cv_method = StratifiedKFold(n_splits=3)
GridSearchCV_RF = GridSearchCV(estimator=RandomForestClassifier(),
                               param_grid=params_RF,
                               cv=cv_method,
                               verbose=1,
                               n_jobs=2,
                               scoring="accuracy",
                               return_train_score=True
                               )

GridSearchCV_RF.fit(x2_train,y2_train)
best_params_RF = GridSearchCV_RF.best_params_
print("Best Hyperparameters for Random Forest aer = ", best_params_RF)
# Out:
# Fitting 3 folds for each of 24 candidates, totalling 72 fits
# Best Hyperparameters for Random Forest aer =  {'criterion': 'gini', 'min_samples_leaf': 1, 'min_samples_split': 2, 'n_estimators': 200}

# %%
best_estimator = GridSearchCV_RF.best_estimator_
best_estimator.fit(x2_train,y2_train)
y2_pred_best = best_estimator.predict(x2_test)
print(classification_report(y2_test,y2_pred_best,zero_division=0.0))
# Out:
#               precision    recall  f1-score   support
#
#            3       0.00      0.00      0.00         4
#            4       0.62      0.16      0.26        31
#            5       0.60      0.58      0.59       235
#            6       0.55      0.74      0.63       358
#            7       0.53      0.30      0.38       138
#            8       0.50      0.04      0.07        26
#            9       0.00      0.00      0.00         1
#
#     accuracy                           0.56       793
#    macro avg       0.40      0.26      0.28       793
# weighted avg       0.56      0.56      0.54       793

# %%
from sklearn.metrics import accuracy_score
print(f"Accuracy of Random Forest Model for white wine quality prediction = {round(accuracy_score(y2_test,y2_pred_best)*100,2)}%")
# Out:
# Accuracy of Random Forest Model for white wine quality prediction = 56.49%

# %% [markdown]
# <h3>Trying different classification models to predict the quality of <b>white wine</b> by calculating accuracy and cv score </h3>

# %%
x2=df1_white.drop(columns=['quality'])
y12=df1_white['quality']
from sklearn.model_selection import cross_val_score, train_test_split
def classify(model, x2, y2):
   x2_train, x2_test, y2_train, y2_test=train_test_split(x2, y2, test_size=0.25, random_state=42)
#train the model
   model.fit(x2_train, y2_train)
   print("Accuracy:", model.score(x2_test, y2_test)*100)
#cross-validation
   score=cross_val_score(model, x2, y2, cv=5) 
   print("CV Score:", np.mean(score) *100)

# %% [markdown]
# <h3>The Logistic Regression model is predicting the quality of white wine with an accuracy of <b>47.32%</b></h3>

# %%
from sklearn.linear_model import LogisticRegression
model= LogisticRegression()
classify(model, x2, y2)
# Out:
# /home/rgukt/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_logistic.py:460: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/rgukt/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_logistic.py:460: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
# ...

# %% [markdown]
# <h3>The Decision Tree Classifier Model is predicting the quality of white wine with an accuracy of <b>44.9%</b></h3>

# %%
from sklearn.tree import DecisionTreeClassifier
model= DecisionTreeClassifier()
classify(model, x2, y2)
# Out:
# Accuracy: 43.99596367305752
# CV Score: 40.39426420573961

# %% [markdown]
# <h3>The Extra Tree Classifier model is predicting the quality of white wine with an accuracy of <b>54.5%</b></h3>

# %%
from sklearn.tree import ExtraTreeClassifier
model= ExtraTreesClassifier()
classify(model, x2, y2)
# Out:
# Accuracy: 54.4904137235116
# CV Score: 52.28495548167679

# %% [markdown]
# <h3>The Gradient Boosting Classifier model is predicting the quality of white wine with an accuracu of <b>51.66%</b></h3>

# %%
from sklearn.ensemble import GradientBoostingClassifier
model= GradientBoostingClassifier()
classify(model, x2, y2)
# Out:
# Accuracy: 51.66498486377397
# CV Score: 51.47751155947877

# %% [markdown]
# <h3>The GaussianNB model is predicting the quality of white wine with an accuracy of <b>45.41%</b></h3>

# %%
from sklearn.naive_bayes import GaussianNB
model= GaussianNB()
classify(model, x2, y2)
# Out:
# Accuracy: 45.40867810292634
# CV Score: 43.52357114652197

# %% [markdown]
# <h3>The AdaBoostClassifier Model is predicting the quality of white wine with an accuracy of <b>49.45%</b></h3>

# %%
from sklearn.ensemble import AdaBoostClassifier
model= AdaBoostClassifier()
classify(model, x2, y2)
# Out:
# Accuracy: 49.44500504540868
# CV Score: 42.262186811367144

# %% [markdown]
# <h3>The SVC model is predicting the quality of white wine with an accuracy of <b>43.7%</b></h3>

# %%
from sklearn.svm import SVC
model= SVC()
classify(model , x2 , y2)
# Out:
# Accuracy: 43.69323915237134
# CV Score: 44.61009846255748

# %% [markdown]
# <h3>The KNeighbors Classifier Model is predicting the quality of white wine with an accuracy of <b>41.67%</b></h3>

# %%
from sklearn.neighbors import KNeighborsClassifier
model= KNeighborsClassifier()
classify(model , x2 , y2)
# Out:
# Accuracy: 41.67507568113017
# CV Score: 40.31831556421721

# %% [markdown]
# <h2>The best model predicting the quality of White wine obtained is Extra Random Forest Classifier model with an accuracy of <b>56.5</b></h2>

# %% [markdown]
# <h2>The best model predicting the quality of Red wine obtained is Extra Trees Classifier model with <b>61.8%</b> accuracy"</h2>

# %% [markdown]
# # Finally Write Conclusion for the dataset

# %% [markdown]
# <h3>In this project, I investigated the feasibility of predicting <b>wine quality</b> using machine learning techniques.<br>
#     <ul>
#         <li> A dataset which is a composition of 2 .csv files is employed:
#             <ul>
#                 <li>'winequality-red.csv'</li>
#                 <li>'winequality-white.csv'</li>
#             </ul>
#         <li>These contain the information on various wine properties and their corresponding quality ratings.</li>
#         <li>The columns in the dataset are as follows:
#      <ul>
#         <li>Fixed acidity</li>
#         <li>Volatile acidity</li>
#         <li>Citric acid</li>
#         <li>Residual sugar</li>
#         <li>Chlorides</li>
#         <li>Free sulfur dioxide</li>
#         <li>Total sulfur dioxide</li>
#         <li>Density</li>
#         <li>pH</li>
#         <li>Sulphates</li>
#         <li>Alcohol</li>
#         <li>Quality</li>
#       </ul><br>
#         <li>I have performed the below stated tasks during this project
#             <ul>
#                 <li>Imported the required Libraries</li><br>
#                 <li>Loaded the dataset using Pandas library</li><br>
#                 <li>Performed the EDA (Exploratory Data Analysis) on the 2 datasets inorder to understand the complete data and get the required insights to proceed further in this prediction journey</li><br>
#                 <li>Dived deep into the sets to check for the Missing values or duplicates if any.</li><br>
#                 <li>Handled the missing values and even got rid of the duplicates present in the data.</li><br>
#                 <li>Visualized the Data in numerous possible ways using the matplotlib and seaborn libraries and obtained the essential insights required for the model development procedure.</li><br>
#                 <li>As a part of the model development and deployment , I have tried to train and test the data with many kinds of clssification models and calculated the Accuracy and Cross validation scores</li><br>
#                 <br>
#         </ul>
#         <li>For instance, the <b>Extra Trees Classifier model</b> achieved an accuracy of <b>61.8%</b> on the <b>Red wine</b> dataset, demonstrating promising potential for classification tasks.</li>
#         <li>The <b>Random Forest Classifier Model</b> achieved an accuracy of <b>56.5%</b> on the <b>white wine</b> dataset , demonstrating efficient potential for classification tasks.</li>
#     </ul>
# </h3>
